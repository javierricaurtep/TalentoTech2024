# %%
#Create the array
array = [[162, 4], [11, 22]]
array[1][0]
# Out:
# 11

# %%
tn = array[0][0]
fp = array[0][1]
fn = array[1][0]
tp = array[1][1]

# %%
#Set Accuracy
accuracy = (tp+tn)/(tp+tn+fp+fn)
accuracy
# Out:
# 0.9246231155778895

# %% [markdown]
# #Clase 1 (Positiva)

# %%
precision1 = tp/(tp+fp)
precision1
# Out:
# 0.8461538461538461

# %%
recall1 = tp/(tp+fn)
recall1
# Out:
# 0.6666666666666666

# %%
f1_score1 = 2*precision1*recall1/(precision1+recall1)
f1_score1
# Out:
# 0.7457627118644068

# %% [markdown]
# #Clase 0 (Negativa)

# %%
true_positive_rate1 = recall1
true_positive_rate1
# Out:
# 0.6666666666666666

# %%
precision0 = tn/(tn+fn)
precision0
# Out:
# 0.9364161849710982

# %%
recall0 = tn/(tn+fp)
recall0
# Out:
# 0.9759036144578314

# %%
f1_score0 = 2*precision0*recall0/(precision0+recall0)
f1_score0
# Out:
# 0.9557522123893805
